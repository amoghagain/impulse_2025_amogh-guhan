# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5955.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/422.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/970.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6179.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/100.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1876.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1041.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4542.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6052.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4248.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3191.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/63.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1364.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1740.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2178.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1337.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1916.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5479.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2947.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/308.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5568.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5414.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5380.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1940.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/693.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4541.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5647.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3535.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4529.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6910.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/91.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4196.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5916.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6936.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1600.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1932.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5275.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1946.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/853.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/995.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4340.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5758.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4261.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5093.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6848.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2644.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6374.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2595.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4491.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1770.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/844.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6896.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1819.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6526.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1489.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5511.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4858.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1712.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3178.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5157.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3984.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1665.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4412.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5730.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1745.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3274.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6495.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6754.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2243.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/616.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2632.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/798.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1007.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4755.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/479.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6804.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1463.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1203.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1455.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3360.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3591.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6591.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2567.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4403.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/500.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/47.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/552.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2295.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4311.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5927.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3738.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/320.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5934.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/864.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1566.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3869.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2985.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/740.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1235.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6783.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6097.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6195.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/697.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/354.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2904.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1334.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1980.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6967.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2291.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6651.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6235.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3359.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3455.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5358.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1014.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/68.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2695.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1601.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2306.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2399.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6297.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5166.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5519.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4416.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3174.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6170.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/925.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/224.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1210.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1212.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1469.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6393.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1768.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3154.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2824.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4651.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3254.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/45.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6917.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4144.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4310.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1472.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5755.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6408.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/675.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2034.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5782.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3138.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2968.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5139.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6340.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2298.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5662.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4148.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5010.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/734.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/536.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4689.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6623.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6334.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2498.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1801.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2042.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4098.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6291.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6944.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6746.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/759.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6792.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2837.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/295.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6076.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1981.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1208.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2263.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4571.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/831.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2945.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3458.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2716.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3974.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3714.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5368.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6626.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1279.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3838.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4518.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/43.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2922.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6270.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3408.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/234.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5705.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1927.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1788.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6090.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4303.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4751.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3023.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5565.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/306.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6355.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6166.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/713.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6443.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1347.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6130.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/619.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3922.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6857.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6324.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5766.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5252.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2843.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4238.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3070.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2652.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3905.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3477.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/62.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4794.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/336.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3064.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1453.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/508.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/315.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6580.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2712.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2215.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6952.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2582.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6486.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3300.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6923.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1127.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6608.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/961.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4832.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3385.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5456.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1845.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3014.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/21.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3281.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6841.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4198.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/784.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6938.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5894.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1506.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3022.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/962.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4239.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1857.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5027.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3161.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6020.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3620.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/671.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4065.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4971.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2077.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1766.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2128.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2411.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1936.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6396.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2521.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4410.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6503.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6193.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2408.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6314.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/195.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/281.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4665.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2162.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4106.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/711.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/50.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4436.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5602.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6524.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1993.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3355.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6389.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6829.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2371.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6145.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6945.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4608.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/572.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5326.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5240.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2892.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1289.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/326.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5301.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4461.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3018.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1646.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6642.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1140.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3121.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/148.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/655.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2099.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6375.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1853.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3352.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/186.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6983.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2804.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6519.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/698.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2475.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1074.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2944.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4210.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/730.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4773.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/926.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4574.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1296.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3865.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3998.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/135.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4029.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3043.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/915.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3196.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/341.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1596.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/7004.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/286.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2540.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/688.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5643.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4795.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4366.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6629.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/502.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1736.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4870.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5984.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3582.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4419.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4741.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6696.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1754.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4739.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5598.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1307.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1593.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6115.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1484.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6423.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1554.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3848.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/498.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3114.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4179.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5887.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1420.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3228.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1787.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6086.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1824.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5424.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/102.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4694.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/899.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5830.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/794.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/644.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4147.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2026.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6601.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2107.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6842.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3327.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2002.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4335.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1293.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1858.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5133.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6009.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3897.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3469.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5541.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4822.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1896.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6013.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/420.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5833.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3630.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/808.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6737.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6654.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4169.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6504.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/322.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3599.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4724.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3941.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3807.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4190.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/24.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6426.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5719.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2889.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/273.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4074.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5099.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2519.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2459.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1475.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5749.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5006.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4725.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5021.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4337.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1169.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1276.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5095.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1492.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/433.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2720.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2871.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4128.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3763.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/70.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5706.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1991.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6942.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5233.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/583.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2465.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5885.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5094.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/537.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6697.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3782.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4039.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4890.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4135.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5972.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4212.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6869.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3368.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2087.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4064.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3130.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/761.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2813.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4464.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2140.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3036.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/783.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1064.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1911.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2405.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5681.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2753.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/160.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1483.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4728.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/445.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/476.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6720.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/871.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1470.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3643.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1784.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/75.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2406.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/944.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/266.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/265.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6420.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6787.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3054.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1085.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3613.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2203.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2565.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1290.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4615.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2917.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5430.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/219.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6412.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1280.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3950.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6726.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6614.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4249.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3349.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2766.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1781.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6852.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1407.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2180.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3919.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3866.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5336.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2302.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2537.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4425.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2739.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5613.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3289.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4223.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6315.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5527.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1339.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5589.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6681.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4357.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/630.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/29.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1741.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2962.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/666.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6253.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5083.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4484.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2103.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2786.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/178.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3549.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3525.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/854.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3354.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3091.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5043.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3948.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6184.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6703.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2990.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5618.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5429.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2483.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4807.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2246.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/119.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5542.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5524.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/259.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2734.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2296.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1057.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5308.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1867.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5361.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5039.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1640.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5072.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/221.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2010.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3490.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/598.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/443.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3701.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3293.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1704.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6805.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/674.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1586.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/96.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3495.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2907.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4108.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6922.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3533.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4217.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3480.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3953.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4962.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1953.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5630.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2428.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1842.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6094.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5516.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1939.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6175.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6727.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/22.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2282.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2553.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/774.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1496.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1437.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3243.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3170.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2828.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2101.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2253.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3532.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2833.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4010.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/406.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/722.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4813.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/351.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/999.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3618.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1944.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4931.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5170.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4988.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5742.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2623.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3766.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2055.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4614.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5227.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1686.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3394.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4842.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1891.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1750.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2706.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5943.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6404.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/97.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6915.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5799.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1073.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3307.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4475.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1892.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2474.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/852.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/370.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5754.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2911.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4442.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1917.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2674.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/497.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3249.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3486.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/254.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3651.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5004.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3774.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3935.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1668.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2987.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1584.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6774.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6925.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4553.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1131.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1094.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6405.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5564.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1222.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2524.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3673.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3370.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1150.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6872.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/6059.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4631.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1863.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3656.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3528.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5058.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/1471.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/5343.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/4627.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/3019.npy
# /kaggle/input/train-data1/train_data/Complex_Partial_Seizures/2797.npy
# ...
# /kaggle/input/val-data/validation_data/Normal/2202.npy
# /kaggle/input/val-data/validation_data/Normal/710.npy
# /kaggle/input/val-data/validation_data/Normal/2823.npy
# /kaggle/input/val-data/validation_data/Normal/3437.npy
# /kaggle/input/val-data/validation_data/Normal/4318.npy
# /kaggle/input/val-data/validation_data/Normal/677.npy
# /kaggle/input/val-data/validation_data/Normal/3277.npy
# /kaggle/input/val-data/validation_data/Normal/3242.npy
# /kaggle/input/val-data/validation_data/Normal/6659.npy
# /kaggle/input/val-data/validation_data/Normal/957.npy
# /kaggle/input/val-data/validation_data/Normal/2138.npy
# /kaggle/input/val-data/validation_data/Normal/2118.npy
# /kaggle/input/val-data/validation_data/Normal/4254.npy
# /kaggle/input/val-data/validation_data/Normal/824.npy
# /kaggle/input/val-data/validation_data/Normal/1410.npy
# /kaggle/input/val-data/validation_data/Normal/3152.npy
# /kaggle/input/val-data/validation_data/Normal/5398.npy
# /kaggle/input/val-data/validation_data/Normal/376.npy
# /kaggle/input/val-data/validation_data/Normal/2883.npy
# /kaggle/input/val-data/validation_data/Normal/3333.npy
# /kaggle/input/val-data/validation_data/Normal/323.npy
# /kaggle/input/val-data/validation_data/Normal/363.npy
# /kaggle/input/val-data/validation_data/Normal/868.npy
# /kaggle/input/val-data/validation_data/Normal/3892.npy
# /kaggle/input/val-data/validation_data/Normal/1521.npy
# /kaggle/input/val-data/validation_data/Normal/5360.npy
# /kaggle/input/val-data/validation_data/Normal/5991.npy
# /kaggle/input/val-data/validation_data/Normal/5910.npy
# /kaggle/input/val-data/validation_data/Normal/4636.npy
# /kaggle/input/val-data/validation_data/Normal/3063.npy
# /kaggle/input/val-data/validation_data/Normal/6996.npy
# /kaggle/input/val-data/validation_data/Normal/6401.npy
# /kaggle/input/val-data/validation_data/Normal/531.npy
# /kaggle/input/val-data/validation_data/Normal/4275.npy
# /kaggle/input/val-data/validation_data/Normal/5250.npy
# /kaggle/input/val-data/validation_data/Normal/5081.npy
# /kaggle/input/val-data/validation_data/Normal/4075.npy
# /kaggle/input/val-data/validation_data/Normal/373.npy
# /kaggle/input/val-data/validation_data/Normal/2156.npy
# /kaggle/input/val-data/validation_data/Normal/527.npy
# /kaggle/input/val-data/validation_data/Normal/4138.npy
# /kaggle/input/val-data/validation_data/Normal/3538.npy
# /kaggle/input/val-data/validation_data/Normal/1387.npy
# /kaggle/input/val-data/validation_data/Normal/5363.npy
# /kaggle/input/val-data/validation_data/Normal/6647.npy
# /kaggle/input/val-data/validation_data/Normal/3204.npy
# /kaggle/input/val-data/validation_data/Normal/3993.npy
# /kaggle/input/val-data/validation_data/Normal/3505.npy
# /kaggle/input/val-data/validation_data/Normal/2096.npy
# /kaggle/input/val-data/validation_data/Normal/2778.npy
# /kaggle/input/val-data/validation_data/Normal/3034.npy
# /kaggle/input/val-data/validation_data/Normal/1251.npy
# /kaggle/input/val-data/validation_data/Normal/2819.npy
# /kaggle/input/val-data/validation_data/Normal/4221.npy
# /kaggle/input/val-data/validation_data/Normal/4231.npy
# /kaggle/input/val-data/validation_data/Normal/4321.npy
# /kaggle/input/val-data/validation_data/Normal/5759.npy
# /kaggle/input/val-data/validation_data/Normal/3048.npy
# /kaggle/input/val-data/validation_data/Normal/3294.npy
# /kaggle/input/val-data/validation_data/Normal/2750.npy
# /kaggle/input/val-data/validation_data/Normal/6752.npy
# /kaggle/input/val-data/validation_data/Normal/1716.npy
# /kaggle/input/val-data/validation_data/Normal/2348.npy
# /kaggle/input/val-data/validation_data/Normal/623.npy
# /kaggle/input/val-data/validation_data/Normal/4097.npy
# /kaggle/input/val-data/validation_data/Normal/6435.npy
# /kaggle/input/val-data/validation_data/Normal/2886.npy
# /kaggle/input/val-data/validation_data/Normal/1693.npy
# /kaggle/input/val-data/validation_data/Normal/5925.npy
# /kaggle/input/val-data/validation_data/Normal/79.npy
# /kaggle/input/val-data/validation_data/Normal/2041.npy
# /kaggle/input/val-data/validation_data/Normal/6553.npy
# /kaggle/input/val-data/validation_data/Normal/1271.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/2196.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/2098.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/5182.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/2816.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/2940.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/6250.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/6326.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/2100.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/4499.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/6025.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/5390.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/6563.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/6937.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/54.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/1878.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/4555.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/483.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/1193.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/3456.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/720.npy
# /kaggle/input/val-data/validation_data/Video_detected_Seizures_with_no_visual_change_over_EEG/594.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6947.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3280.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/193.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1994.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6034.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/481.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2224.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3339.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6984.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1708.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1838.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1414.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2269.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6221.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/781.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1036.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6322.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/4269.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3304.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2366.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1286.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1503.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5773.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1133.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3852.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2555.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5347.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/676.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3398.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/610.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3708.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/342.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6555.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2078.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3445.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/495.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3094.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3554.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/17.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2686.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1695.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/4183.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3199.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5393.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2339.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6040.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/4961.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3190.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/546.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5106.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6603.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5037.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3322.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2153.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/4611.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/66.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2840.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/4428.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2403.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5448.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3218.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5932.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5258.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/263.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6217.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2934.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2195.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/634.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2780.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/4455.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/937.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3390.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6084.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3617.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3069.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/4785.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1862.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6724.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3074.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/431.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2175.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1262.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5080.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3688.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2209.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6079.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/4965.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/350.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2217.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/258.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/4006.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1423.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3379.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3889.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2317.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1428.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1820.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1636.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6854.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6628.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5399.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/442.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/522.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6532.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3086.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3371.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/721.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1404.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2759.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1663.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/28.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1433.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1117.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/372.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1564.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3137.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1111.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/855.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5141.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/2615.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3825.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/573.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/716.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6575.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3684.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/4720.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5645.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/712.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5743.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6980.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6892.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/3110.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/800.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/564.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/5324.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/1868.npy
# /kaggle/input/val-data/validation_data/Electrographic_Seizures/6860.npy

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
import os
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import ReduceLROnPlateau
from scipy.signal import resample

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Linear(in_channels, out_channels)
        self.conv2 = nn.Linear(out_channels, out_channels)
        self.bn1 = nn.BatchNorm1d(out_channels)
        self.bn2 = nn.BatchNorm1d(out_channels)
        self.dropout = nn.Dropout(0.3)
        
        # Adjust input dimension if needed
        self.shortcut = nn.Sequential()
        if in_channels != out_channels:
            self.shortcut = nn.Linear(in_channels, out_channels)
            
    def forward(self, x):
        residual = self.shortcut(x)
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.dropout(out)
        out = self.bn2(self.conv2(out))
        out += residual
        out = F.relu(out)
        return out

# %%
# Enhanced VAE architecture
class ImprovedVAE(nn.Module):
    def __init__(self, input_dim, hidden_dims, latent_dim, n_classes):
        super(ImprovedVAE, self).__init__()
        self.input_dim = input_dim
        self.latent_dim = latent_dim
        
        # Encoder
        self.encoder_layers = nn.ModuleList()
        current_dim = input_dim
        for hidden_dim in hidden_dims:
            self.encoder_layers.append(ResidualBlock(current_dim, hidden_dim))
            current_dim = hidden_dim
            
        self.mu = nn.Linear(hidden_dims[-1], latent_dim)
        self.log_var = nn.Linear(hidden_dims[-1], latent_dim)
        
        # Decoder
        self.decoder_layers = nn.ModuleList()
        decoder_dims = hidden_dims[::-1]
        current_dim = latent_dim + n_classes  # Concatenate class labels
        
        for hidden_dim in decoder_dims:
            self.decoder_layers.append(ResidualBlock(current_dim, hidden_dim))
            current_dim = hidden_dim
            
        self.final_layer = nn.Linear(decoder_dims[-1], input_dim)
        
        # Classifier
        classifier_dims = [latent_dim] + [128, 64]
        self.classifier = nn.ModuleList()
        for i in range(len(classifier_dims)-1):
            self.classifier.append(ResidualBlock(classifier_dims[i], classifier_dims[i+1]))
        self.classifier_output = nn.Linear(classifier_dims[-1], n_classes)

# %%
def encode(self, x):
        for layer in self.encoder_layers:
            x = layer(x)
        return self.mu(x), self.log_var(x)
    
def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std
    
def decode(self, z, labels):
        # One-hot encode labels
        label_onehot = F.one_hot(labels, num_classes=4).float()
        x = torch.cat([z, label_onehot], dim=1)
        
        for layer in self.decoder_layers:
            x = layer(x)
        return torch.tanh(self.final_layer(x))
    
def classify(self, x):
        mu, _ = self.encode(x)
        x = mu
        for layer in self.classifier:
            x = layer(x)
        return self.classifier_output(x)
    
def forward(self, x, labels):
        mu, log_var = self.encode(x)
        z = self.reparameterize(mu, log_var)
        classification = self.classify(x)
        recon_x = self.decode(z, labels)
        return recon_x, classification, mu, log_var

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        if alpha is not None:
            self.alpha = torch.tensor(alpha)

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        pt = torch.exp(-ce_loss)
        focal_loss = (1 - pt) ** self.gamma * ce_loss
        
        if self.alpha is not None:
            alpha_t = self.alpha[targets].to(inputs.device)
            focal_loss = alpha_t * focal_loss
            
        return focal_loss.mean()

# %%
class EEGDataAugmentation:
    @staticmethod
    def add_gaussian_noise(signal, noise_factor=0.05):
        noise = np.random.normal(0, noise_factor, signal.shape)
        return signal + noise
    
    @staticmethod
    def time_shift(signal, shift_max=0.2):
        shift = int(len(signal) * np.random.uniform(-shift_max, shift_max))
        return np.roll(signal, shift)
    
    @staticmethod
    def scaling(signal, scale_factor=0.1):
        factor = np.random.uniform(1 - scale_factor, 1 + scale_factor)
        return signal * factor
    
    @staticmethod
    def random_resample(signal, resample_factor_range=(0.8, 1.2)):
        factor = np.random.uniform(*resample_factor_range)
        new_length = int(len(signal) * factor)
        return resample(signal, new_length)
    
    @staticmethod
    def mixup(signal1, signal2, alpha=0.2):
        """Perform mixup augmentation between two signals"""
        lambda_param = np.random.beta(alpha, alpha)
        mixed_signal = lambda_param * signal1 + (1 - lambda_param) * signal2
        return mixed_signal
    
    @staticmethod
    def spectral_augment(signal, max_mask_size=0.1):
        """Apply spectral augmentation"""
        fft = np.fft.fft(signal)
        mask_size = int(len(fft) * max_mask_size)
        mask_start = np.random.randint(0, len(fft) - mask_size)
        fft[mask_start:mask_start + mask_size] = 0
        return np.real(np.fft.ifft(fft))

# %%
class EEGDataset(Dataset):
    def __init__(self, data_dir, augment=False, class_weights=None):
        self.data = []
        self.labels = []
        self.augment = augment
        self.augmenter = EEGDataAugmentation()
        self.class_weights = class_weights
        self.label_map = {
            'Normal': 0,
            'Complex_Partial_Seizures': 1,
            'Electrographic_Seizures': 2,
            'Video_detected_Seizures_with_no_visual_change_over_EEG': 3
        }
        
        # Load and process data
        for class_name, label in self.label_map.items():
            class_path = os.path.join(data_dir, class_name)
            if os.path.exists(class_path):
                class_data = []
                for file_name in os.listdir(class_path):
                    if file_name.endswith('.npy'):
                        try:
                            data = np.load(os.path.join(class_path, file_name))
                            if len(data.shape) == 1:
                                data = data.reshape(1, -1)
                            elif len(data.shape) > 2:
                                data = data.reshape(data.shape[0], -1)
                            class_data.append(data)
                        except Exception as e:
                            print(f"Error loading file {file_name}: {str(e)}")
                
                if class_data:
                    class_data = np.vstack(class_data)
                    # Apply extra augmentation for minority classes (2 and 3)
                    if label in [2, 3] and self.augment:
                        aug_factor = 3 if label == 2 else 2
                        aug_data = []
                        for _ in range(aug_factor - 1):
                            aug_data.append(self.augment_batch(class_data))
                        class_data = np.vstack([class_data] + aug_data)
                    
                    self.data.append(class_data)
                    self.labels.extend([label] * len(class_data))
        
        self.data = np.vstack(self.data)
        self.labels = np.array(self.labels)
        
        # Standardize the data
        self.scaler = StandardScaler()
        self.data = self.scaler.fit_transform(self.data)

    def augment_batch(self, batch):
        augmented = []
        for signal in batch:
            aug_signal = self.augment_signal(signal)
            augmented.append(aug_signal)
        return np.array(augmented)

    def augment_signal(self, signal):
        # Enhanced augmentation strategy
        augmentations = [
            (self.augmenter.add_gaussian_noise, 0.8),
            (self.augmenter.time_shift, 0.7),
            (self.augmenter.scaling, 0.7),
            (self.augmenter.spectral_augment, 0.5)
        ]
        
        augmented_signal = signal.copy()
        for aug_func, prob in augmentations:
            if np.random.random() < prob:
                augmented_signal = aug_func(augmented_signal)
        
        return augmented_signal

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        signal = self.data[idx]
        label = self.labels[idx]
        
        if self.augment:
            # Apply more aggressive augmentation for class 2
            if label == 2:
                signal = self.augment_signal(signal)
            elif np.random.random() < 0.5:
                signal = self.augment_signal(signal)
        
        return torch.FloatTensor(signal), label

# %%
def plot_class_distributions(train_dataset, synthetic_data, synthetic_labels):
    plt.figure(figsize=(15, 5))
    
    # Original data distribution
    plt.subplot(1, 2, 1)
    class_counts = np.bincount(train_dataset.labels)
    plt.bar(range(len(class_counts)), class_counts)
    plt.title('Original Class Distribution')
    plt.xlabel('Class')
    plt.ylabel('Count')
    
    # Synthetic data distribution
    plt.subplot(1, 2, 2)
    synthetic_counts = np.bincount(synthetic_labels)
    plt.bar(range(len(synthetic_counts)), synthetic_counts)
    plt.title('Synthetic Class Distribution')
    plt.xlabel('Class')
    plt.ylabel('Count')
    
    plt.tight_layout()
    plt.show()

# %%
def plot_class_samples(train_dataset, vae, device, num_samples=5):
    """Plot original and reconstructed samples for each class."""
    vae.eval()
    plt.figure(figsize=(20, 12))
    
    for class_idx in range(4):
        # Get samples from the specific class
        class_samples = train_dataset.data[train_dataset.labels == class_idx]
        class_labels = torch.full((num_samples,), class_idx)
        
        # Select random samples
        random_indices = np.random.choice(len(class_samples), num_samples, replace=False)
        samples = torch.FloatTensor(class_samples[random_indices]).to(device)
        
        with torch.no_grad():
            # Get reconstructions
            recon_samples, _, _, _ = vae(samples, class_labels.to(device))
            
            # Plot original samples
            plt.subplot(4, 2, 2*class_idx + 1)
            for i in range(num_samples):
                plt.plot(samples[i].cpu().numpy() + i*2)
            plt.title(f'Original Samples - Class {class_idx}')
            plt.xlabel('Time')
            plt.ylabel('Amplitude')
            
            # Plot reconstructed samples
            plt.subplot(4, 2, 2*class_idx + 2)
            for i in range(num_samples):
                plt.plot(recon_samples[i].cpu().numpy() + i*2)
            plt.title(f'Reconstructed Samples - Class {class_idx}')
            plt.xlabel('Time')
            plt.ylabel('Amplitude')
    
    plt.tight_layout()
    plt.show()

# %%
def plot_latent_space(vae, train_dataset, device):
    """Visualize the latent space using PCA projection."""
    from sklearn.decomposition import PCA
    
    vae.eval()
    all_data = torch.FloatTensor(train_dataset.data).to(device)
    all_labels = train_dataset.labels
    
    with torch.no_grad():
        # Get latent representations
        mu, _ = vae.encode(all_data)
        latent_space = mu.cpu().numpy()
        
        # Apply PCA
        pca = PCA(n_components=2)
        latent_2d = pca.fit_transform(latent_space)
        
        # Plot
        plt.figure(figsize=(10, 8))
        scatter = plt.scatter(latent_2d[:, 0], latent_2d[:, 1], c=all_labels, 
                            cmap='viridis', alpha=0.6)
        plt.colorbar(scatter)
        plt.title('Latent Space Visualization (PCA)')
        plt.xlabel('First Principal Component')
        plt.ylabel('Second Principal Component')
        plt.show()

# %%
def plot_reconstruction_loss_by_class(vae, train_loader, device):
    """Plot reconstruction loss distribution for each class."""
    vae.eval()
    losses_by_class = {i: [] for i in range(4)}
    
    with torch.no_grad():
        for data, labels in train_loader:
            data = data.to(device)
            labels = labels.to(device)
            recon_batch, _, _, _ = vae(data, labels)
            
            # Calculate reconstruction loss for each sample
            recon_loss = F.mse_loss(recon_batch, data, reduction='none').mean(dim=1)
            
            # Store losses by class
            for label, loss in zip(labels.cpu().numpy(), recon_loss.cpu().numpy()):
                losses_by_class[label].append(loss)
    
    plt.figure(figsize=(12, 6))
    plt.boxplot([losses_by_class[i] for i in range(4)], labels=[f'Class {i}' for i in range(4)])
    plt.title('Reconstruction Loss Distribution by Class')
    plt.xlabel('Class')
    plt.ylabel('Reconstruction Loss')
    plt.show()

# %%
def train_improved_vae(vae, train_loader, n_epochs, device, lr=1e-3):
    optimizer = torch.optim.Adam(vae.parameters(), lr=lr, weight_decay=1e-5)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
    
    # Initialize Focal Loss with adjusted class weights
    class_weights = torch.tensor([1.0, 1.2, 2.5, 1.5]).to(device)  # Increased weight for class 2
    criterion = FocalLoss(alpha=class_weights, gamma=2.5)  # Increased gamma for harder examples
    
    losses = []
    accuracies = []
    best_loss = float('inf')
    patience_counter = 0
    patience_limit = 20
    
    for epoch in range(n_epochs):
        total_loss = 0
        correct = 0
        total = 0
        vae.train()
        
        for batch_idx, (data, labels) in enumerate(train_loader):
            data = data.to(device)
            labels = labels.to(device)
            
            optimizer.zero_grad()
            recon_batch, classification, mu, log_var = vae(data, labels)
            
            # Losses with dynamic weighting
            recon_loss = F.mse_loss(recon_batch, data)
            kl_loss = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
            class_loss = criterion(classification, labels)
            
            # Adaptive loss weighting
            beta = min(epoch / (n_epochs * 0.1), 1.0)
            classification_weight = 2.0 if epoch > n_epochs * 0.2 else 1.0  # Increase classification weight later
            loss = recon_loss + beta * 0.1 * kl_loss + classification_weight * class_loss
            
            loss.backward()
            torch.nn.utils.clip_grad_norm_(vae.parameters(), max_norm=1.0)
            optimizer.step()
            
            total_loss += loss.item()
            
            # Calculate accuracy
            _, predicted = classification.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()
        
        avg_loss = total_loss / len(train_loader.dataset)
        accuracy = 100. * correct / total
        
        losses.append(avg_loss)
        accuracies.append(accuracy)
        
        scheduler.step(avg_loss)
        
        if avg_loss < best_loss:
            best_loss = avg_loss
            patience_counter = 0
        else:
            patience_counter += 1
        
        if patience_counter >= patience_limit:
            print(f"Early stopping at epoch {epoch+1}")
            break
        
        if (epoch + 1) % 5 == 0:
            print(f'Epoch {epoch+1}, Loss: {avg_loss:.4f}, Accuracy: {accuracy:.2f}%')
    
    return losses, accuracies



def generate_synthetic_data(vae, n_samples_per_class, n_classes, device, noise_scale=1.0):
    vae.eval()
    synthetic_data = []
    synthetic_labels = []
    
    # Adjust samples per class based on class distribution
    class_multipliers = {
        0: 1,
        1: 1,
        2: 3,  # Generate more samples for class 2
        3: 2
    }
    
    with torch.no_grad():
        for class_idx in range(n_classes):
            adjusted_samples = n_samples_per_class * class_multipliers[class_idx]
            n_batches = 5
            samples_per_batch = adjusted_samples // n_batches
            
            for _ in range(n_batches):
                z = torch.randn(samples_per_batch, vae.latent_dim).to(device) * noise_scale
                labels = torch.full((samples_per_batch,), class_idx, dtype=torch.long).to(device)
                synthetic_samples = vae.decode(z, labels)
                
                # Add noise to synthetic samples for better generalization
                if class_idx == 2:  # For class 2
                    noise = torch.randn_like(synthetic_samples) * 0.05
                    synthetic_samples = synthetic_samples + noise
                
                synthetic_data.append(synthetic_samples.cpu().numpy())
                synthetic_labels.extend([class_idx] * samples_per_batch)
    
    return np.vstack(synthetic_data), np.array(synthetic_labels)

# %%
def main():
    # Hyperparameters
    hidden_dims = [512, 256, 128]
    latent_dim = 64
    n_classes = 4
    batch_size = 32
    n_epochs = 200
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    
    # Load and prepare data
    train_dataset = EEGDataset('/kaggle/input/train-data1/train_data', augment=True)
    
    # Calculate class weights for balanced sampling
    class_counts = np.bincount(train_dataset.labels)
    class_weights = 1.0 / class_counts
    sample_weights = class_weights[train_dataset.labels]
    sampler = WeightedRandomSampler(sample_weights, len(sample_weights))
    
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        sampler=sampler,
        num_workers=4,
        pin_memory=True
    )
    
    # Initialize and train model
    input_dim = train_dataset.data.shape[1]
    vae = ImprovedVAE(input_dim, hidden_dims, latent_dim, n_classes).to(device)
    losses, accuracies = train_improved_vae(vae, train_loader, n_epochs, device)

    # Plot training metrics
    plot_training_metrics(losses, accuracies)
    
    # Generate synthetic data
    n_samples_per_class = 500
    synthetic_data, synthetic_labels = generate_synthetic_data(
        vae, n_samples_per_class, n_classes, device, noise_scale=0.8
    )

    # Plot class distributions
    plot_class_distributions(train_dataset, synthetic_data, synthetic_labels)


    print("Generating visualizations...")
    plot_class_samples(train_dataset, vae, device)
    plot_latent_space(vae, train_dataset, device)
    plot_reconstruction_loss_by_class(vae, train_loader, device)


    # Evaluate on validation set
    val_dataset = EEGDataset('/kaggle/input/val-data/validation_data', augment=False)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
    
    vae.eval()
    predictions = []
    true_labels = []
    
    with torch.no_grad():
        for data, labels in val_loader:
            data = data.to(device)
            classification = vae.classify(data)
            pred = classification.argmax(dim=1).cpu().numpy()
            predictions.extend(pred)
            true_labels.extend(labels.numpy())
    
    print("\nClassification Report:")
    print(classification_report(true_labels, predictions))

# %%
if __name__ == "__main__":
    main()
